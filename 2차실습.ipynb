# %%
print(4//2)
print(int(5.0))
# Out:
# 2
# 5

# %%
나이=10
type(나이)
print(bin(나이))
# Out:
# 0b1010

# %%
print(float(5))
print(int(5.0))
print("5", "5.0")
#print(type("5"). type("5.0"))
# Out:
# 5.0
# 5
# 5 5.0
